# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/SriyaHarshini19/PixelToPrediction/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# My Lane as an ML Task: Scoring
#
# I chose scoring because my project gives each webpage a score based on things like impressions, CTR, search volume, and how old the page is. This score helps me find which pages have more opportunity for improvement and which ones I should focus on updating first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# I would predict an opportunity score for each webpage. This label comes from a defined rule, because the opportunity score is not directly given in the dataset. I create the score using factors like impressions, CTR, and how recently the page was updated. It acts as a proxy for identifying which pages have more potential for improvement.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# I would use Precision@K as my success metric. It measures how many of the top-ranked pages selected by my model are actually useful pages to update. For example, if I select the top 10 pages and 8 of them turn out to be good opportunities, my Precision@10 is 80%. I would consider 80% or higher a good result.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# Unit of Analysis
#
# One row in my dataframe represents one webpage. Each row contains information about that webpage, such as impressions, CTR, search volume, clicks, and how recently it was updated. I use these features to calculate the opportunity score and identify which webpages should be prioritized for improvement.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# A fixed rule may work for simple cases, but webpage performance depends on many factors like impressions, CTR, search volume, clicks, and how recently the page was updated. These factors can interact in different ways, so one simple if-statement may not capture the full pattern. ML can learn these patterns from the data and give more flexible predictions or scores.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
