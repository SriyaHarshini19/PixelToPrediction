# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/SriyaHarshini19/PixelToPrediction/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# I chose the SEO Content Optimization lane because I want to use website performance data to help identify which pages should be updated first. This project uses metrics such as impressions, clicks, CTR, and page freshness to support better content decisions. It is a practical problem where machine learning can help prioritize work using data.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
#  Decision, Action, and Cost
#
# #My project helps website owners and SEO specialists decide which webpages should be updated first to improve search performance. The action is to update or optimize the selected pages based on data. A wrong recommendation could waste time and resources by focusing on pages that are unlikely to improve while missing pages that have a greater opportunity to increase traffic.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

# Load the starter CSV
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# Check dataset size
print("Dataset:", df.shape[0], "rows,", df.shape[1], "columns")

# Calculate average CTR for each position tier
ctr_by_position = df.groupby("position_tier")["ctr"].mean().sort_values(ascending=False)

print("\nAverage CTR by position tier:")
print(ctr_by_position)

# Calculate the CTR gap between top_3 and deep
top3_ctr = ctr_by_position.get("top_3")
deep_ctr = ctr_by_position.get("deep")

print(f"\nTop 3 average CTR: {top3_ctr:.2f}%")
print(f"Deep average CTR: {deep_ctr:.2f}%")
print(f"CTR difference: {top3_ctr - deep_ctr:.2f} percentage points")

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# The dataset contains website pages with SEO performance metrics. The number of pages, average impressions, and average CTR provide useful information for identifying patterns in page performance. These measurements suggest that the dataset is suitable for studying which pages may benefit from content updates and further analysis over the next seven weeks.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
