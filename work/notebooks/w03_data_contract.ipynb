# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/SriyaHarshini19/PixelToPrediction/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %% [markdown]
# Unit of analysis: One row represents one content item for one client on one report date.
# Time window: March 2026, using the fact_content_daily_performance table as the development window.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %% [markdown]
# Feature: search_volume, impressions_90d, position, days_since_last_update, word_count
#
# Label: ctr
#
# Context: client, content, report_date, month
#
# Excluded: Any future-period CTR or performance fields derived from the outcome window, because they would not be known at the decision moment and could cause data leakage.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
SELECT
  client_id,
  content_id,
  report_date,
  COUNT(*) AS row_count
FROM `fact_content_daily_performance`
WHERE report_date BETWEEN '2026-03-01' AND '2026-03-31'
GROUP BY client_id, content_id, report_date
HAVING COUNT(*) > 1
LIMIT 5;

# %%
SELECT
  COUNT(*) AS row_count,
  MIN(report_date) AS first_date,
  MAX(report_date) AS last_date
FROM `fact_content_daily_performance`
WHERE report_date BETWEEN '2026-03-01' AND '2026-03-31';

# %%
SELECT
  COUNT(*) AS total_rows,
  COUNTIF(ga4_data_available IS TRUE) AS available_rows
FROM `fact_content_daily_performance`
WHERE report_date BETWEEN '2026-03-01' AND '2026-03-31';

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# Data limitation: The data cannot fully represent CTR performance for every client because the available history is unbalanced across clients. Some early rows are GSC-only or have limited GA4 availability, and rolling windows such as impressions_90d can overlap across observation periods. Therefore, comparisons across clients or time periods may not always be directly comparable.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [X] Every section above is filled — markdown thinking AND the code that backs it
# - [X] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [X] No client names, URLs, or private queries anywhere
# - [X] My claims use careful words: observed, measured, directional, decision-support
# - [X] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
